# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ### 03_01 - Linear Regression
#
# Goals:
#
# * Understand how to prepare data for linear regression by selecting the relevant numerical features and the target variable.
# * Learn to split the data into training and testing sets using `train_test_split`
# * Evaluate the performance of the linear regression model

# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '2.0.2'

# %%
url = 'data/ames-housing-dataset.zip'
raw = pd.read_csv(url, engine='pyarrow', dtype_backend='pyarrow')

# make function
def shrink_ints(df):
    mapping = {}
    for col in df.dtypes[df.dtypes=='int64[pyarrow]'].index:
        max_ = df[col].max()
        min_ = df[col].min()
        if min_ < 0:
            continue
        if max_ < 255:
            mapping[col] = 'uint8[pyarrow]'
        elif max_ < 65_535:
            mapping[col] = 'uint16[pyarrow]'
        elif max_ <  4294967295:
            mapping[col] = 'uint32[pyarrow]'
    return df.astype(mapping)


def clean_housing(df):
    return (df
     .assign(**df.select_dtypes('string').replace('', 'Missing').astype('category'),
             **{'Garage Yr Blt': df['Garage Yr Blt'].clip(upper=df['Year Built'].max())})
     .pipe(shrink_ints)
    )    

housing = clean_housing(raw)

# %%
from sklearn import linear_model, model_selection, preprocessing

X = housing.select_dtypes('number').drop(columns='SalePrice')
y = housing.SalePrice

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, random_state=42)

# %%
X_train
# Out:
#       Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 844     845  907181100           20            68      9017             7
# 2730   2731  905351045          150          <NA>      1700             7
# 2793   2794  907255050           20          <NA>     14781             8
# 1187   1188  534127230           20            85     11050             6
# 2770   2771  907130110           60            65     12438             6
# ...     ...        ...          ...           ...       ...           ...
# 1638   1639  527226040          190           195     41600             5
# 1095   1096  528290090           60          <NA>      7750             7
# 1130   1131  528490080           60            64      8791             6
# 1294   1295  902109160           50            81      7308             5
# 860     861  907227110           85            60      7200             5
#
#       Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 844              5        1999            1999             0  ...
# 2730             5        1980            1981             0  ...
# 2793             5        2001            2002           178  ...
# 1187             5        1968            1968             0  ...
# 2770             5        1995            1995            68  ...
# ...            ...         ...             ...           ...  ...
# 1638             5        1969            1990             0  ...
# 1095             5        2002            2002          <NA>  ...
# 1130             5        2003            2003             0  ...
# 1294             5        1920            1950             0  ...
# 860              8        1972            2003             0  ...
#
#       Garage Area  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 844           666             0             35               0           0
# 2730          450           188             36               0           0
# 2793          748           198            150               0           0
# 1187          512            25              0               0           0
# 2770          473           413             91               0           0
# ...           ...           ...            ...             ...         ...
# 1638          828           144              0               0           0
# 1095          403           100             35               0           0
# 1130          673           216             56               0           0
# 1294          225             0              0             236           0
# 860           396           192              0               0           0
#
#       Screen Porch  Pool Area  Misc Val  Mo Sold  Yr Sold
# 844              0          0         0        9     2009
# 2730           200          0         0        4     2006
# 2793             0          0         0        8     2006
# 1187           192          0         0       10     2008
# 2770             0          0         0        8     2006
# ...            ...        ...       ...      ...      ...
# 1638             0          0         0       11     2007
# 1095             0          0         0        4     2008
# 1130             0          0         0        5     2008
# 1294             0          0         0        6     2008
# 860              0          0         0        4     2009
#
# [2197 rows x 38 columns]

# %%
y_train
# Out:
# 844     192000
# 2730    148400
# 2793    275000
# 1187    150000
# 2770    187000
#          ...
# 1638    155000
# 1095    176000
# 1130    207500
# 1294    122250
# 860     133900
# Name: SalePrice, Length: 2197, dtype: uint32[pyarrow]

# %%
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 lr = linear_model.LinearRegression()
# ----> 2 lr.fit(X_train, y_train)
#       3 lr.score(X_test, y_test)
#
# File ~/pyStatsTraining/env/lib/python3.11/site-packages/sklearn/linear_model/_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# File ~/pyStatsTraining/env/lib/python3.11/site-packages/sklearn/base.py:584, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582         y = check_array(y, input_name="y", **check_y_params)
#     583     else:
# --> 584         X, y = check_X_y(X, y, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/pyStatsTraining/env/lib/python3.11/site-packages/sklearn/utils/validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File ~/pyStatsTraining/env/lib/python3.11/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/pyStatsTraining/env/lib/python3.11/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
X_train.isna().any()
# Out:
# Order              False
# PID                False
# MS SubClass        False
# Lot Frontage        True
# Lot Area           False
# Overall Qual       False
# Overall Cond       False
# Year Built         False
# Year Remod/Add     False
# Mas Vnr Area        True
# BsmtFin SF 1        True
# BsmtFin SF 2        True
# Bsmt Unf SF         True
# Total Bsmt SF       True
# 1st Flr SF         False
# 2nd Flr SF         False
# Low Qual Fin SF    False
# Gr Liv Area        False
# Bsmt Full Bath      True
# Bsmt Half Bath      True
# Full Bath          False
# Half Bath          False
# Bedroom AbvGr      False
# Kitchen AbvGr      False
# TotRms AbvGrd      False
# Fireplaces         False
# Garage Yr Blt       True
# Garage Cars         True
# Garage Area         True
# Wood Deck SF       False
# Open Porch SF      False
# Enclosed Porch     False
# 3Ssn Porch         False
# Screen Porch       False
# Pool Area          False
# Misc Val           False
# Mo Sold            False
# Yr Sold            False
# dtype: bool

# %%
import pandas as pd
url = 'data/ames-housing-dataset.zip'
raw = pd.read_csv(url, engine='pyarrow', dtype_backend='pyarrow')

# make function
def shrink_ints(df):
    mapping = {}
    for col in df.dtypes[df.dtypes=='int64[pyarrow]'].index:
        max_ = df[col].max()
        min_ = df[col].min()
        if min_ < 0:
            continue
        if max_ < 255:
            mapping[col] = 'uint8[pyarrow]'
        elif max_ < 65_535:
            mapping[col] = 'uint16[pyarrow]'
        elif max_ <  4294967295:
            mapping[col] = 'uint32[pyarrow]'
    return df.astype(mapping)


def clean_housing_no_na(df):
    return (df
     .assign(**df.select_dtypes('string').replace('', 'Missing').astype('category'),
             **{'Garage Yr Blt': df['Garage Yr Blt'].clip(upper=df['Year Built'].max())})
     .pipe(shrink_ints)
     .pipe(lambda df_: df_.assign(**df_.select_dtypes('number').fillna(0)))
    )    
    

housing2 = clean_housing_no_na(raw)

# %%
X = housing2.select_dtypes('number').drop(columns='SalePrice')
y = housing2.SalePrice

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, random_state=42)

# %%
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.8434707037243693

# %% [markdown]
# ### 03_02 - Interpreting Linear Regression Models

# %%
lr.coef_
# Out:
# array([-1.03814738e+01,  9.02411860e-07, -1.63050576e+02,  2.81284818e+01,
#         4.92668567e-01,  1.73466716e+04,  4.84079679e+03,  3.91645014e+02,
#         1.76965630e+02,  2.73066661e+01,  1.05967266e+01,  4.13482938e+00,
#        -2.72938016e+00,  1.20021765e+01,  1.87157914e+01,  2.54896651e+01,
#        -9.18032342e+00,  3.50251328e+01,  7.35666770e+03, -1.51315712e+03,
#        -1.41742224e+02, -5.39960782e+03, -7.73039749e+03, -1.43271176e+04,
#         1.36191997e+03,  3.51407523e+03, -1.31044446e+01,  1.03630326e+04,
#         1.49225509e+01,  1.99789208e+01, -6.04065085e+00,  2.04208107e+01,
#        -5.67776073e+00,  7.08392922e+01, -3.93865793e+01, -8.71867696e+00,
#         2.35118730e+02, -8.15826993e+03])

# %%
lr.intercept_
# Out:
# 15240773.746056803

# %%
lr.feature_names_in_
# Out:
# array(['Order', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area',
#        'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add',
#        'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF',
#        'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd',
#        'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold'],
#       dtype=object)

# %%
pd.Series(lr.coef_, index=lr.feature_names_in_)
# Out:
# Order             -1.038147e+01
# PID                9.024119e-07
# MS SubClass       -1.630506e+02
# Lot Frontage       2.812848e+01
# Lot Area           4.926686e-01
# Overall Qual       1.734667e+04
# Overall Cond       4.840797e+03
# Year Built         3.916450e+02
# Year Remod/Add     1.769656e+02
# Mas Vnr Area       2.730667e+01
# BsmtFin SF 1       1.059673e+01
# BsmtFin SF 2       4.134829e+00
# Bsmt Unf SF       -2.729380e+00
# Total Bsmt SF      1.200218e+01
# 1st Flr SF         1.871579e+01
# 2nd Flr SF         2.548967e+01
# Low Qual Fin SF   -9.180323e+00
# Gr Liv Area        3.502513e+01
# Bsmt Full Bath     7.356668e+03
# Bsmt Half Bath    -1.513157e+03
# Full Bath         -1.417422e+02
# Half Bath         -5.399608e+03
# Bedroom AbvGr     -7.730397e+03
# Kitchen AbvGr     -1.432712e+04
# TotRms AbvGrd      1.361920e+03
# Fireplaces         3.514075e+03
# Garage Yr Blt     -1.310444e+01
# Garage Cars        1.036303e+04
# Garage Area        1.492255e+01
# Wood Deck SF       1.997892e+01
# Open Porch SF     -6.040651e+00
# Enclosed Porch     2.042081e+01
# 3Ssn Porch        -5.677761e+00
# Screen Porch       7.083929e+01
# Pool Area         -3.938658e+01
# Misc Val          -8.718677e+00
# Mo Sold            2.351187e+02
# Yr Sold           -8.158270e+03
# dtype: float64

# %%
(pd.Series(lr.coef_, index=lr.feature_names_in_)
 .sort_values()
 .plot.barh())
# Out:
# <Axes: >

# %%
(pd.Series(lr.coef_, index=lr.feature_names_in_)
 .pipe(lambda ser: ser[ser.abs() > 100])
 .sort_values()
 .plot.barh())
# Out:
# <Axes: >

# %%
(pd.Series(lr.coef_, index=lr.feature_names_in_)
 .pipe(lambda ser: ser[ser.abs() > 100])
 .sort_values()
 .index
)
# Out:
# Index(['Kitchen AbvGr', 'Yr Sold', 'Bedroom AbvGr', 'Half Bath',
#        'Bsmt Half Bath', 'MS SubClass', 'Full Bath', 'Year Remod/Add',
#        'Mo Sold', 'Year Built', 'TotRms AbvGrd', 'Fireplaces', 'Overall Cond',
#        'Bsmt Full Bath', 'Garage Cars', 'Overall Qual'],
#       dtype='object')

# %% [markdown]
# ### 03_03 - Standardizing Values
#
# Goals:
#
# * Understand the concept of standardization
# * Learn to use the `StandardScaler` class
# * Evaluate the impact of standardization on the performance of the linear regression model using the coefficient of determination (R-squared) score.
# * Visualize the coefficients of the linear regression model using a horizontal bar plot.

# %%
X = housing2.select_dtypes('number').drop(columns='SalePrice')
y = housing2.SalePrice

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, random_state=42)

std = preprocessing.StandardScaler()
X_train = std.fit_transform(X_train)
X_test = std.transform(X_test)

# %%
# was .84
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.8414203565713573

# %%
(pd.Series(lr.coef_, index=X.columns)
 .sort_values()
 .plot.barh())
# Out:
# <Axes: >

# %%
(pd.Series(lr.coef_, index=X.columns)
 .sort_values()
# .plot.barh()
)
# Out:
# Total Bsmt SF     -6.125367e+17
# 2nd Flr SF        -4.222478e+17
# 1st Flr SF        -3.814527e+17
# Low Qual Fin SF   -4.434336e+16
# Yr Sold           -1.066701e+04
# Order             -8.741487e+03
# MS SubClass       -7.401218e+03
# Garage Yr Blt     -6.074536e+03
# Bedroom AbvGr     -5.968635e+03
# Misc Val          -5.678880e+03
# Kitchen AbvGr     -3.171953e+03
# Half Bath         -2.428311e+03
# Pool Area         -1.149332e+03
# Bsmt Half Bath    -4.009648e+02
# Open Porch SF     -3.067355e+02
# 3Ssn Porch        -1.098841e+02
# Full Bath         -1.067897e+02
# PID                7.546269e+01
# Mo Sold            6.463570e+02
# Lot Frontage       1.179903e+03
# Enclosed Porch     1.464378e+03
# TotRms AbvGrd      2.003889e+03
# Fireplaces         2.256835e+03
# Wood Deck SF       2.595169e+03
# Garage Area        3.100219e+03
# Year Remod/Add     3.657691e+03
# Bsmt Full Bath     3.849043e+03
# Lot Area           3.949053e+03
# Screen Porch       3.963028e+03
# Mas Vnr Area       4.449456e+03
# Overall Cond       5.454838e+03
# Garage Cars        8.013017e+03
# Year Built         1.227660e+04
# Overall Qual       2.393416e+04
# BsmtFin SF 2       2.344768e+17
# Gr Liv Area        5.026278e+17
# Bsmt Unf SF        6.068271e+17
# BsmtFin SF 1       6.307527e+17
# dtype: float64

# %%
(pd.Series(lr.coef_, index=X.columns)
 .sort_values()
 .pipe(lambda ser: ser[ser.abs() > 1e8])
 .plot.barh()
)
# Out:
# <Axes: >

# %%
(pd.Series(lr.coef_, index=X.columns)
 .sort_values()
 .pipe(lambda ser: ser[ser.abs() > 1e8])
 .index
)
# Out:
# Index(['Total Bsmt SF', '2nd Flr SF', '1st Flr SF', 'Low Qual Fin SF',
#        'BsmtFin SF 2', 'Gr Liv Area', 'Bsmt Unf SF', 'BsmtFin SF 1'],
#       dtype='object')

# %%
simple_feats = set(['Kitchen AbvGr', 'Yr Sold', 'Bedroom AbvGr', 'Half Bath',
       'Bsmt Half Bath', 'MS SubClass', 'Full Bath', 'Year Remod/Add',
       'Mo Sold', 'Year Built', 'TotRms AbvGrd', 'Fireplaces', 'Overall Cond',
       'Bsmt Full Bath', 'Garage Cars', 'Overall Qual'])
std_feats = set(['Total Bsmt SF', '2nd Flr SF', '1st Flr SF', 'Low Qual Fin SF',
       'BsmtFin SF 2', 'Gr Liv Area', 'Bsmt Unf SF', 'BsmtFin SF 1'])
print(sorted(simple_feats | std_feats))
# Out:
# ['1st Flr SF', '2nd Flr SF', 'Bedroom AbvGr', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Bsmt Unf SF', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Fireplaces', 'Full Bath', 'Garage Cars', 'Gr Liv Area', 'Half Bath', 'Kitchen AbvGr', 'Low Qual Fin SF', 'MS SubClass', 'Mo Sold', 'Overall Cond', 'Overall Qual', 'TotRms AbvGrd', 'Total Bsmt SF', 'Year Built', 'Year Remod/Add', 'Yr Sold']

# %%
# Look at correlations 
(X
 .assign(SalePrice=y)
 .corr()
 .loc[['SalePrice', '1st Flr SF', '2nd Flr SF', 'Bedroom AbvGr', 'Bsmt Full Bath', 'Bsmt Half Bath', 
       'Bsmt Unf SF', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Fireplaces', 'Full Bath', 
       'Garage Cars', 'Gr Liv Area', 'Half Bath', 'Kitchen AbvGr', 'Low Qual Fin SF',
       'MS SubClass', 'Mo Sold', 'Overall Cond', 'Overall Qual', 'TotRms AbvGrd', 
       'Total Bsmt SF', 'Year Built', 'Year Remod/Add', 'Yr Sold']]
 .style
 .background_gradient(cmap='RdBu', vmin=-1, vmax=1)
 .set_sticky(axis='index') 
)
# Out:
# <style type="text/css">
# #T_f2ee5 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_f2ee5 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_f2ee5_row0_col0, #T_f2ee5_row0_col16, #T_f2ee5_row0_col19, #T_f2ee5_row2_col32, #T_f2ee5_row3_col11, #T_f2ee5_row3_col26, #T_f2ee5_row4_col1, #T_f2ee5_row4_col21, #T_f2ee5_row5_col3, #T_f2ee5_row5_col27, #T_f2ee5_row5_col30, #T_f2ee5_row5_col38, #T_f2ee5_row6_col21, #T_f2ee5_row6_col34, #T_f2ee5_row6_col37, #T_f2ee5_row7_col0, #T_f2ee5_row8_col21, #T_f2ee5_row8_col22, #T_f2ee5_row8_col23, #T_f2ee5_row9_col6, #T_f2ee5_row11_col0, #T_f2ee5_row11_col19, #T_f2ee5_row11_col23, #T_f2ee5_row13_col11, #T_f2ee5_row13_col12, #T_f2ee5_row13_col18, #T_f2ee5_row14_col11, #T_f2ee5_row14_col13, #T_f2ee5_row14_col27, #T_f2ee5_row15_col38, #T_f2ee5_row16_col32, #T_f2ee5_row18_col3, #T_f2ee5_row18_col4, #T_f2ee5_row18_col25, #T_f2ee5_row21_col23, #T_f2ee5_row24_col12, #T_f2ee5_row24_col30 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_f2ee5_row0_col27, #T_f2ee5_row11_col38 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_f2ee5_row0_col28, #T_f2ee5_row4_col10, #T_f2ee5_row7_col18 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
# }
# #T_f2ee5_row0_col29, #T_f2ee5_row4_col13, #T_f2ee5_row9_col27, #T_f2ee5_row10_col13, #T_f2ee5_row11_col25, #T_f2ee5_row20_col28, #T_f2ee5_row21_col18, #T_f2ee5_row21_col20 {
#   background-color: #a9d1e5;
#   color: #000000;
# }
# #T_f2ee5_row0_col30, #T_f2ee5_row12_col8, #T_f2ee5_row23_col17 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_f2ee5_row0_col31, #T_f2ee5_row6_col2, #T_f2ee5_row16_col12, #T_f2ee5_row18_col9 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_f2ee5_row0_col32, #T_f2ee5_row0_col36, #T_f2ee5_row2_col4, #T_f2ee5_row3_col34, #T_f2ee5_row5_col25, #T_f2ee5_row5_col35, #T_f2ee5_row8_col31, #T_f2ee5_row9_col19, #T_f2ee5_row9_col36, #T_f2ee5_row13_col4, #T_f2ee5_row13_col33, #T_f2ee5_row14_col36, #T_f2ee5_row14_col37, #T_f2ee5_row15_col34, #T_f2ee5_row16_col7, #T_f2ee5_row16_col24, #T_f2ee5_row17_col23, #T_f2ee5_row17_col25, #T_f2ee5_row17_col30, #T_f2ee5_row17_col38, #T_f2ee5_row18_col35, #T_f2ee5_row20_col2, #T_f2ee5_row20_col33, #T_f2ee5_row21_col32, #T_f2ee5_row22_col2, #T_f2ee5_row23_col32, #T_f2ee5_row23_col37, #T_f2ee5_row24_col8, #T_f2ee5_row24_col23 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_f2ee5_row0_col33, #T_f2ee5_row3_col3, #T_f2ee5_row13_col29, #T_f2ee5_row20_col7, #T_f2ee5_row22_col24 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_f2ee5_row0_col34, #T_f2ee5_row2_col23, #T_f2ee5_row3_col5, #T_f2ee5_row4_col26, #T_f2ee5_row5_col34, #T_f2ee5_row6_col23, #T_f2ee5_row7_col3, #T_f2ee5_row8_col25, #T_f2ee5_row8_col33, #T_f2ee5_row9_col11, #T_f2ee5_row12_col2, #T_f2ee5_row12_col35, #T_f2ee5_row14_col12, #T_f2ee5_row14_col15, #T_f2ee5_row16_col17, #T_f2ee5_row19_col22, #T_f2ee5_row23_col3 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_f2ee5_row0_col35, #T_f2ee5_row2_col37, #T_f2ee5_row3_col2, #T_f2ee5_row3_col8, #T_f2ee5_row3_col37, #T_f2ee5_row4_col20, #T_f2ee5_row4_col23, #T_f2ee5_row5_col28, #T_f2ee5_row5_col37, #T_f2ee5_row8_col17, #T_f2ee5_row8_col32, #T_f2ee5_row9_col0, #T_f2ee5_row10_col18, #T_f2ee5_row11_col35, #T_f2ee5_row11_col37, #T_f2ee5_row12_col11, #T_f2ee5_row13_col32, #T_f2ee5_row14_col0, #T_f2ee5_row14_col4, #T_f2ee5_row14_col18, #T_f2ee5_row14_col32, #T_f2ee5_row15_col13, #T_f2

# %% [markdown]
# ### 03_04 - Regression with XGBoost
#
# Goals:
#
# * Learn to use the XGBoost library (`xgboost`) for regression tasks.
# * Evaluate the performance of the XGBoost model.
# * Explore the importance of features in the XGBoost model using the feature importances.

# %%
# cons looking under the hood is more difficult
# pros: it handles missing data, works with non-numeric data, does not  
# require standardization

# %%
X = housing2.select_dtypes('number').drop(columns='SalePrice')
y = housing2.SalePrice

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, random_state=42)

std = preprocessing.StandardScaler().set_output(transform='pandas')
X_train = std.fit_transform(X_train)
X_test = std.transform(X_test)

# %%
import xgboost as xgb
# was .84
xg = xgb.XGBRegressor()
xg.fit(X_train, y_train)
xg.score(X_test, y_test)
# Out:
# 0.8990089684311526

# %%
pd.Series(xg.feature_importances_, index=X_train.columns).sort_values().plot.barh(figsize=(3,12))
# Out:
# <Axes: >

# %%
# Use categories
# (Need to convert pyarrow numbers to pandas 1.x numbers)
X_cat = (housing.assign(**housing.select_dtypes('number').astype('Int64')).drop(columns='SalePrice'))

y_cat = housing.SalePrice
X_cat_train, X_cat_test, y_cat_train, y_cat_test = model_selection.train_test_split(X_cat, y_cat, random_state=42)
xg_cat = xgb.XGBRegressor(enable_categorical=True, tree_method='hist')
xg_cat.fit(X_cat_train, y_cat_train)
xg_cat.score(X_cat_test, y_cat_test)
# Out:
# 0.9156284763324242

# %%
pd.Series(xg_cat.feature_importances_, index=xg_cat.feature_names_in_).sort_values().plot.barh(figsize=(3,12))
# Out:
# <Axes: >

# %% [markdown]
# ### 03_05 - Challenge: Predict Ames
# * Create a linear regression model using the top 5 features from the (non-categorical) XGBoost model
# * What is the `.score` of the model?

# %%
xg
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
xg.feature_importances_
# Out:
# array([5.9863774e-04, 1.6078486e-03, 1.3475008e-03, 1.0129152e-03,
#        3.7261853e-03, 4.7258279e-01, 6.2119309e-03, 5.6510735e-03,
#        7.3023238e-03, 1.5394163e-03, 1.2190409e-02, 9.2779438e-04,
#        9.0641214e-04, 1.1845408e-02, 1.8865503e-02, 1.6694061e-02,
#        6.2936457e-04, 3.2038119e-02, 6.8123643e-03, 1.6271221e-03,
#        8.3641320e-02, 8.8814343e-04, 3.5277426e-03, 8.8023497e-03,
#        9.7144413e-04, 6.5039359e-03, 3.1909666e-03, 2.7262524e-01,
#        1.9710080e-03, 2.2682515e-03, 8.9909654e-04, 5.9488975e-04,
#        4.4255095e-04, 5.4381997e-03, 2.5395483e-03, 3.9533287e-04,
#        1.1828801e-03, 0.0000000e+00], dtype=float32)

# %%
top5 = list(pd.Series(xg.feature_importances_, index=X_train.columns)
 .sort_values()
 .index
 [-5:]
)

lr_top5 = linear_model.LinearRegression()
lr_top5.fit(X_train.loc[:, top5], y_train)
lr_top5.score(X_test.loc[:, top5], y_test)
# Out:
# 0.792412229091269
